# %% [markdown]
# <a href="https://colab.research.google.com/github/Mayur619/NMT/blob/master/NMT_TF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-6f9c4b66-28eb-4e7a-b8b4-7b348517836d" name="files[]" multiple disabled />
#      <output id="result-6f9c4b66-28eb-4e7a-b8b4-7b348517836d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving answers to answers
# Saving questions to questions
# User uploaded file "answers" with length 502719 bytes
# User uploaded file "questions" with length 200488 bytes

# %%
import tensorflow as tf
import os
import numpy as np
import copy
import _pickle as pickle

# %%
def load_data(path):
    input_file=os.path.join(path)
    with open(input_file,'r') as file:
        data=file.read()
    return data

# %%
source_path='questions'
target_path='answers'
source_text=load_data(source_path)
target_text=load_data(target_path)

# %%
CODES={'<PAD>':0,'<EOS>':1,'<UNK>':2,'<GO>':3}
def create_lookup_tables(text):
    vocab=set(text.split())
    word2int=copy.copy(CODES)
    for idx,word in enumerate(vocab,len(CODES)):
        word2int[word]=idx
    int2word={idx:word for word,idx in word2int.items()}
    return word2int,int2word

# %%
def text_to_ids(source_text,target_text,source_word2int,target_word2int):
    source_text_id=[]
    target_text_id=[]
    
    source_sentences=source_text.split('\n')
    target_sentences=target_text.split('\n')
    
    for i in range(len(source_sentences)):
        source_sentence=[]
        target_sentence=[]
        
        source_tokens=source_sentences[i].split(' ')
        target_tokens=target_sentences[i].split(' ')
        try:
          for word in source_tokens:
              if word!='':
                  source_sentence.append(source_word2int[word])
          for word in target_tokens:
              if word!='':
                  target_sentence.append(target_word2int[word])
        except KeyError:
          continue
        target_sentence.append(target_word2int['<EOS>'])
        source_text_id.append(source_sentence)
        target_text_id.append(target_sentence)
        
    return source_text_id,target_text_id

# %%
def preprocess_and_save(source_text,target_text):
    source_text=source_text.lower()
    target_text=target_text.lower()

    source_word2int,source_int2word=create_lookup_tables(source_text)
    target_word2int,target_int2word=create_lookup_tables(target_text)
    
    source_text,target_text=text_to_ids(source_text,target_text,source_word2int,target_word2int)
    pickle.dump(((source_text,target_text),(source_word2int,target_word2int),(source_int2word,target_int2word)),open('preprocessed.pkl','wb'))

# %%
preprocess_and_save(source_text,target_text)

# %%
def load_preprocessed():
    with open('preprocessed.pkl','rb') as file:
        return pickle.load(file)

# %%
(source_text_int,target_text_int),(source_word2int,target_word2int),_=load_preprocessed()

# %%
def model_inputs():
    inputs=tf.placeholder(tf.int32,[None,None],name='Inputs')
    targets=tf.placeholder(tf.int32,[None,None],name='Targets')
    target_sequence_length=tf.placeholder(tf.int32,[None],name='target_sequence_length')
    max_target_length=tf.reduce_max(target_sequence_length)
    source_sequence_length=tf.placeholder(tf.int32,shape=(None,),name='source_sequence_length')
    
    return inputs,targets,source_sequence_length,target_sequence_length,max_target_length

# %%
def hparams():
    learning_rate=tf.placeholder(tf.float32,name='learning_rate',shape=())
    keep_prob=tf.placeholder(tf.float32,name='keep_prob',shape=())
    return learning_rate,keep_prob

# %%
def process_decoder_input(target_data,target_word2int,batch_size):
    go_id=target_word2int['<GO>']
    after_slice=tf.strided_slice(target_data,[0,0],[batch_size,-1],[1,1])
    after_concat=tf.concat([tf.fill([batch_size,1],go_id),after_slice],1)
    return after_concat

# %%
def encoding_layer(rnn_inputs,rnn_size,num_layers,keep_prob,source_vocab_size,encoding_embedding_size):
    embedding=tf.contrib.layers.embed_sequence(rnn_inputs,vocab_size=source_vocab_size,embed_dim=encoding_embedding_size)
    stacked_cell=tf.contrib.rnn.MultiRNNCell([tf.contrib.rnn.DropoutWrapper(tf.contrib.rnn.LSTMCell(rnn_size),keep_prob) for _ in range(num_layers)])
    output,state=tf.nn.dynamic_rnn(stacked_cell,embedding,dtype=tf.float32)
    return output,state

# %%
def attention(encoder_outputs,rnn_size,source_sequence_length):
  #attention_state=tf.transpose(encoder_outputs,[1,0,2])
  attention_mechanism=tf.contrib.seq2seq.LuongAttention(rnn_size,encoder_outputs,memory_sequence_length=source_sequence_length)
  return attention_mechanism

# %%
def decoding_layer_train(encoder_state,encoder_outputs,rnn_size,dec_cell,dec_embed_input,source_sequence_length,target_sequence_length,max_summary_length,output_layer,keep_prob,batch_size):
    dec_cell=tf.contrib.rnn.DropoutWrapper(dec_cell,output_keep_prob=keep_prob)
    dec_cell=tf.contrib.seq2seq.AttentionWrapper(dec_cell,attention(encoder_outputs,rnn_size,source_sequence_length),attention_layer_size=rnn_size)
    helper=tf.contrib.seq2seq.TrainingHelper(dec_embed_input,target_sequence_length)
    decoder=tf.contrib.seq2seq.BasicDecoder(dec_cell,helper,dec_cell.zero_state(dtype=tf.float32,batch_size=batch_size),output_layer)
    outputs,_,_=tf.contrib.seq2seq.dynamic_decode(decoder,impute_finished=True,maximum_iterations=max_summary_length)
    return outputs

# %%
def decoding_layer_infer(encoder_state,encoder_outputs,rnn_size,dec_cell,dec_embeddings,source_sequence_length,start_of_sequence_id,end_of_sequence_id,max_target_sequence_length,vocab_size,output_layer,batch_size,keep_prob):
    dec_cell=tf.contrib.rnn.DropoutWrapper(dec_cell,output_keep_prob=keep_prob)
    dec_cell=tf.contrib.seq2seq.AttentionWrapper(dec_cell,attention(encoder_outputs,rnn_size,source_sequence_length),attention_layer_size=rnn_size)
    helper=tf.contrib.seq2seq.GreedyEmbeddingHelper(dec_embeddings,tf.fill([batch_size],start_of_sequence_id),end_of_sequence_id)
    decoder=tf.contrib.seq2seq.BasicDecoder(dec_cell,helper,dec_cell.zero_state(dtype=tf.float32,batch_size=batch_size),output_layer)
    output,_,_=tf.contrib.seq2seq.dynamic_decode(decoder,impute_finished=True,maximum_iterations=max_target_sequence_length)
    return output

# %%
def decoding_layer(dec_input,encoder_state,encoder_output,source_sequence_length,target_sequence_length,max_target_sequence_length,rnn_size,num_layers,target_word2int,target_vocab_size,batch_size,keep_prob,decoding_embedding_size):
    target_vocab_size=len(target_word2int)
    dec_embeddings=tf.Variable(tf.random_uniform([target_vocab_size,decoding_embedding_size]))
    dec_embed_input=tf.nn.embedding_lookup(dec_embeddings,dec_input)
    cells=tf.contrib.rnn.MultiRNNCell([tf.contrib.rnn.LSTMCell(rnn_size) for _ in range(num_layers)])
    with tf.variable_scope('decode'):
        output_layer=tf.layers.Dense(target_vocab_size)
        train_output=decoding_layer_train(encoder_state,encoder_output,rnn_size,cells,dec_embed_input,source_sequence_length,target_sequence_length,max_target_sequence_length,output_layer,keep_prob,batch_size)
    with tf.variable_scope('decode',reuse=True):
        infer=decoding_layer_infer(encoder_state,encoder_output,rnn_size,cells,dec_embeddings,source_sequence_length,target_word2int['<GO>'],target_word2int['<EOS>'],max_target_sequence_length,target_vocab_size,output_layer,batch_size,keep_prob)
    return train_output,infer

# %%
def seq2seq_model(input_data,target_data,keep_prob,batch_size,source_sequence_length,target_sequence_length,max_target_sequence_length,source_vocab_size,target_vocab_size,enc_embedding_size,dec_embedding_size,rnn_size,num_layers,target_word2int):
    enc_output,enc_state=encoding_layer(input_data,rnn_size,num_layers,keep_prob,source_vocab_size,enc_embedding_size)
    dec_inputs=process_decoder_input(target_data,target_word2int,batch_size)
    train_output,infer_output=decoding_layer(dec_inputs,enc_state,enc_output,source_sequence_length,target_sequence_length,max_target_sequence_length,rnn_size,num_layers,target_word2int,target_vocab_size,batch_size,keep_prob,dec_embedding_size)
    return train_output,infer_output

# %%
display_step=50
epochs=500
batch_size=32
rnn_size=256
num_layers=3
encoding_embedding_size=200
decoding_embedding_size=200
learning_rate=0.001
keep_prob=0.75

# %%
savepath='./model/model_s'
(source_int_text,target_int_text),(source_word2int,target_word2int),_=load_preprocessed()
max_target_sequence_length=max([len(s) for s in source_int_text])
train_graph=tf.Graph()
with train_graph.as_default():
    input_data,target_data,source_sequence_length,target_sequence_length,max_target_sequence_length=model_inputs()
    lr,keep_probability=hparams()
    train_logits,infer_logits=seq2seq_model(input_data,target_data,keep_probability,batch_size,source_sequence_length,target_sequence_length,max_target_sequence_length,len(source_word2int),len(target_word2int),encoding_embedding_size,decoding_embedding_size,rnn_size,num_layers,target_word2int)
    training_logits=tf.identity(train_logits.rnn_output,name='logits')
    inference_logits=tf.identity(infer_logits.sample_id,name='predictions')
    masks=tf.sequence_mask(target_sequence_length,max_target_sequence_length,dtype=tf.float32,name='mask')
    with tf.name_scope('optimization'):
        cost=tf.contrib.seq2seq.sequence_loss(training_logits,target_data,masks)
        optimizer=tf.train.AdamOptimizer(lr)
        gradients=optimizer.compute_gradients(cost)
        capped_grad=[(tf.clip_by_value(grad,-1.,1.),var) for grad,var in gradients if grad is not None]
        train_op=optimizer.apply_gradients(capped_grad)
# Out:
# WARNING: The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From <ipython-input-14-5ef9512bd1bf>:3: LSTMCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.LSTMCell, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:From <ipython-input-14-5ef9512bd1bf>:3: MultiRNNCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.StackedRNNCells, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:From <ipython-input-14-5ef9512bd1bf>:4: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/rnn_cell_impl.py:1259: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/array_grad.py:425: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.

# %%
def pad_sentence_batch(sentence_batch,pad_int):
    max_sentence=max([len(s) for s in sentence_batch])
    return [sentence + [pad_int]*(max_sentence-len(sentence)) for sentence in sentence_batch]

def get_batches(sources,targets,batch_size,source_pad_int,target_pad_int):
    for batch_i in range(0,len(sources)//batch_size):
        start_i=batch_i*batch_size
        
        sources_batch=sources[start_i:start_i+batch_size]
        targets_batch=targets[start_i:start_i+batch_size]
        
        pad_source_batch=np.array(pad_sentence_batch(sources_batch,source_pad_int))
        pad_target_batch=np.array(pad_sentence_batch(targets_batch,target_pad_int))
        
        pad_source_lengths=[]
        pad_target_lengths=[]
        
        for source in pad_source_batch:
            pad_source_lengths.append(len(source))
        for target in pad_target_batch:
            pad_target_lengths.append(len(target))
        yield pad_source_batch,pad_target_batch,pad_source_lengths,pad_target_lengths

# %%
from datetime import datetime
 
def get_accuracy(target,logits):
    max_seq=max(target.shape[1],logits.shape[1])
    if max_seq-target.shape[1]:
        target=np.pad(target,[(0,0),(0,max_seq-target.shape[1])],'constant')
    if max_seq-logits.shape[1]:
        logits=np.pad(logits,[(0,0),(0,max_seq-logits.shape[1])],'constant')
    return np.mean(np.equal(target,logits))
train_source=source_int_text[batch_size:]
train_target=target_int_text[batch_size:]
validation_source=source_int_text[:batch_size]
validation_target=target_int_text[:batch_size]

(valid_source_batch,valid_target_batch,valid_source_length,valid_target_length)=next(get_batches(validation_source,validation_target,batch_size,source_word2int['<PAD>'],target_word2int['<PAD>']))
with tf.Session(graph=train_graph) as sess:
    sess.run(tf.global_variables_initializer())
    for epoch_i in range(epochs):
        for batch_i,(source_batch,target_batch,source_length,target_length) in enumerate(get_batches(train_source,train_target,batch_size,source_word2int['<PAD>'],target_word2int['<PAD>'])):
            _,loss=sess.run([train_op,cost],{input_data:source_batch,target_data:target_batch,source_sequence_length:source_length,target_sequence_length:target_length,lr:learning_rate,keep_probability:keep_prob})
            if batch_i%display_step==0 and batch_i>0:
                batch_train_logits=sess.run(inference_logits,{input_data:source_batch,source_sequence_length:source_length,target_sequence_length:target_length,keep_probability:1.0})
                batch_valid_logits=sess.run(inference_logits,{input_data:valid_source_batch,source_sequence_length:valid_source_length,target_sequence_length:valid_target_length,keep_probability:1.0})
                train_acc=get_accuracy(target_batch,batch_train_logits)
                valid_acc=get_accuracy(valid_target_batch,batch_valid_logits)
                print('[',str(datetime.now()),']','Epoch {:>3} batch {:>4}/{} - Train accuracy: {:>6.4f}, Validation accuracy: {:>6.4f}, Loss: {:>6.4f}'.format(epoch_i,batch_i,len(source_int_text)//batch_size,train_acc,valid_acc,loss))
    saver=tf.train.Saver()
    saver.save(sess,savepath)
    print('Model trained and saved')
# Out:
# [ 2019-02-16 06:51:44.727463 ] Epoch   0 batch   50/67 - Train accuracy: 0.5354, Validation accuracy: 0.5379, Loss: 4.0757
# [ 2019-02-16 06:52:22.404177 ] Epoch   1 batch   50/67 - Train accuracy: 0.5354, Validation accuracy: 0.5379, Loss: 3.3999
# [ 2019-02-16 06:53:00.213909 ] Epoch   2 batch   50/67 - Train accuracy: 0.0145, Validation accuracy: 0.0151, Loss: 3.2796
# [ 2019-02-16 06:53:38.146608 ] Epoch   3 batch   50/67 - Train accuracy: 0.0145, Validation accuracy: 0.0151, Loss: 3.2393
# [ 2019-02-16 06:54:15.929480 ] Epoch   4 batch   50/67 - Train accuracy: 0.0137, Validation accuracy: 0.0151, Loss: 3.1466
# [ 2019-02-16 06:54:53.845400 ] Epoch   5 batch   50/67 - Train accuracy: 0.0141, Validation accuracy: 0.0162, Loss: 3.0897
# [ 2019-02-16 06:55:31.619962 ] Epoch   6 batch   50/67 - Train accuracy: 0.0130, Validation accuracy: 0.0151, Loss: 3.0655
# [ 2019-02-16 06:56:09.407806 ] Epoch   7 batch   50/67 - Train accuracy: 0.0137, Validation accuracy: 0.0147, Loss: 3.0336
# [ 2019-02-16 06:56:47.190842 ] Epoch   8 batch   50/67 - Train accuracy: 0.0099, Validation accuracy: 0.0324, Loss: 3.0347
# [ 2019-02-16 06:57:24.833519 ] Epoch   9 batch   50/67 - Train accuracy: 0.0088, Validation accuracy: 0.0048, Loss: 2.9785
# [ 2019-02-16 06:58:02.693509 ] Epoch  10 batch   50/67 - Train accuracy: 0.0084, Validation accuracy: 0.0074, Loss: 2.9413
# [ 2019-02-16 06:58:40.599937 ] Epoch  11 batch   50/67 - Train accuracy: 0.0476, Validation accuracy: 0.0434, Loss: 2.9313
# [ 2019-02-16 06:59:18.380941 ] Epoch  12 batch   50/67 - Train accuracy: 0.4657, Validation accuracy: 0.4665, Loss: 2.9238
# [ 2019-02-16 06:59:55.931088 ] Epoch  13 batch   50/67 - Train accuracy: 0.4970, Validation accuracy: 0.4827, Loss: 2.8923
# [ 2019-02-16 07:00:33.532492 ] Epoch  14 batch   50/67 - Train accuracy: 0.4729, Validation accuracy: 0.4419, Loss: 2.8918
# [ 2019-02-16 07:01:11.428350 ] Epoch  15 batch   50/67 - Train accuracy: 0.2611, Validation accuracy: 0.1952, Loss: 2.8839
# [ 2019-02-16 07:01:49.305378 ] Epoch  16 batch   50/67 - Train accuracy: 0.3114, Validation accuracy: 0.2805, Loss: 2.8499
# [ 2019-02-16 07:02:27.124584 ] Epoch  17 batch   50/67 - Train accuracy: 0.4005, Validation accuracy: 0.3460, Loss: 2.8092
# [ 2019-02-16 07:03:04.932986 ] Epoch  18 batch   50/67 - Train accuracy: 0.1597, Validation accuracy: 0.0504, Loss: 2.7965
# [ 2019-02-16 07:03:42.797501 ] Epoch  19 batch   50/67 - Train accuracy: 0.0549, Validation accuracy: 0.0129, Loss: 2.7726
# [ 2019-02-16 07:04:20.562916 ] Epoch  20 batch   50/67 - Train accuracy: 0.1109, Validation accuracy: 0.0173, Loss: 2.7356
# [ 2019-02-16 07:04:58.416487 ] Epoch  21 batch   50/67 - Train accuracy: 0.0111, Validation accuracy: 0.0077, Loss: 2.7028
# [ 2019-02-16 07:05:36.267739 ] Epoch  22 batch   50/67 - Train accuracy: 0.0473, Validation accuracy: 0.0103, Loss: 2.6852
# [ 2019-02-16 07:06:14.066060 ] Epoch  23 batch   50/67 - Train accuracy: 0.0492, Validation accuracy: 0.0371, Loss: 2.6596
# [ 2019-02-16 07:06:51.960903 ] Epoch  24 batch   50/67 - Train accuracy: 0.0305, Validation accuracy: 0.0162, Loss: 2.6550
# [ 2019-02-16 07:07:29.847183 ] Epoch  25 batch   50/67 - Train accuracy: 0.0236, Validation accuracy: 0.0158, Loss: 2.6401
# [ 2019-02-16 07:08:07.757470 ] Epoch  26 batch   50/67 - Train accuracy: 0.2031, Validation accuracy: 0.2070, Loss: 2.6199
# [ 2019-02-16 07:08:45.747038 ] Epoch  27 batch   50/67 - Train accuracy: 0.2367, Validation accuracy: 0.1500, Loss: 2.5734
# [ 2019-02-16 07:09:23.565526 ] Epoch  28 batch   50/67 - Train accuracy: 0.1898, Validation accuracy: 0.2658, Loss: 2.5565
# [ 2019-02-16 07:10:01.397756 ] Epoch  29 batch   50/67 - Train accuracy: 0.1368, Validation accuracy: 0.2055, Loss: 2.5014
# [ 2019-02-16 07:10:39.405522 ] Epoch  30 batch   50/67 - Train accuracy: 0.3445, Validation accuracy: 0.3276, Loss: 2.4427
# [ 2019-02-16 07:11:17.208286 ] Epoch  31 batch   50/67 - Train accuracy: 0.3540, Validation accuracy: 0.3739, Loss: 2.3971
# [ 2019-02-16 07:11:55.049945 ] Epoch  32 batch   50/67 - Train accuracy: 0.3518, Validation accuracy: 0.2967, Loss: 2.3696
# [ 2019-02-16 07:12:32.969565 ] Epoch  33 batch   50/67 - Train accuracy: 0.2492, Validation accuracy: 0.1647, Loss: 2.3593
# [ 2019-02-16 07:13:10.717930 ] Epoch  34 batch   50/67 - Train accuracy: 0.2329, Validation accuracy: 0.2401, Loss: 2.3210
# [ 2019-02-16 07:13:48.497453 ] Epoch  35 batch   50/67 - Train accuracy: 0.3106, Validation accuracy: 0.3066, Loss: 2.3557
# [ 2019-02-16 07:14:26.288768 ] Epoch  36 batch   50/67 - Train accuracy: 0.4181, Validation accuracy: 0.2923, Loss: 2.3211
# [ 2019-02-16 07:15:04.117057 ] Epoch  37 batch   50/67 - Train accuracy: 0.2165, Validation accuracy: 0.1460, Loss: 2.3530
# [ 2019-02-16 07:15:42.127957 ] Epoch  38 batch   50/67 - Train accuracy: 0.1536, Validation accuracy: 0.2037, Loss: 2.2255
# [ 2019-02-16 07:16:19.963658 ] Epoch  39 batch   50/67 - Train accuracy: 0.2934, Validation accuracy: 0.3390, Loss: 2.1951
# [ 2019-02-16 07:16:57.796291 ] Epoch  40 batch   50/67 - Train accuracy: 0.2458, Validation accuracy: 0.2434, Loss: 2.1658
# [ 2019-02-16 07:17:35.709358 ] Epoch  41 batch   50/67 - Train accuracy: 0.1993, Validation accuracy: 0.1732, Loss: 2.1341
# [ 2019-02-16 07:18:13.609329 ] Epoch  42 batch   50/67 - Train accuracy: 0.1780, Validation accuracy: 0.1103, Loss: 2.1327
# [ 2019-02-16 07:18:51.576146 ] Epoch  43 batch   50/67 - Train accuracy: 0.2447, Validation accuracy: 0.2772, Loss: 2.0565
# [ 2019-02-16 07:19:29.456009 ] Epoch  44 batch   50/67 - Train accuracy: 0.3026, Validation accuracy: 0.2702, Loss: 2.0067
# [ 2019-02-16 07:20:07.299696 ] Epoch  45 batch   50/67 - Train accuracy: 0.3746, Validation accuracy: 0.3838, Loss: 1.9607
# [ 2019-02-16 07:20:45.149828 ] Epoch  46 batch   50/67 - Train accuracy: 0.4223, Validation accuracy: 0.4750, Loss: 1.9217
# [ 2019-02-16 07:21:22.888739 ] Epoch  47 batch   50/67 - Train accuracy: 0.4383, Validation accuracy: 0.4680, Loss: 1.9129
# [ 2019-02-16 07:22:00.635554 ] Epoch  48 batch   50/67 - Train accuracy: 0.4668, Validation accuracy: 0.4982, Loss: 1.8975
# [ 2019-02-16 07:22:38.344945 ] Epoch  49 batch   50/67 - Train accuracy: 0.4748, Validation accuracy: 0.5066, Loss: 1.8910
# [ 2019-02-16 07:23:16.092670 ] Epoch  50 batch   50/67 - Train accuracy: 0.4939, Validation accuracy: 0.5062, Loss: 1.8523
# [ 2019-02-16 07:23:53.667513 ] Epoch  51 batch   50/67 - Train accuracy: 0.4585, Validation accuracy: 0.4926, Loss: 1.7928
# [ 2019-02-16 07:24:31.542938 ] Epoch  52 batch   50/67 - Train accuracy: 0.4062, Validation accuracy: 0.4482, Loss: 1.7682
# [ 2019-02-16 07:25:09.442123 ] Epoch  53 batch   50/67 - Train accuracy: 0.3876, Validation accuracy: 0.3669, Loss: 1.7553
# [ 2019-02-16 07:25:47.327022 ] Epoch  54 batch   50/67 - Train accuracy: 0.4078, Validation accuracy: 0.4132, Loss: 1.7281
# [ 2019-02-16 07:26:25.278879 ] Epoch  55 batch   50/67 - Train accuracy: 0.4173, Validation accuracy: 0.3482, Loss: 1.7118
# [ 2019-02-16 07:27:03.212536 ] Epoch  56 batch   50/67 - Train accuracy: 0.4272, Validation accuracy: 0.4158, Loss: 1.6615
# [ 2019-02-16 07:27:41.063922 ] Epoch  57 batch   50/67 - Train accuracy: 0.4173, Validation accuracy: 0.4261, Loss: 1.6167
# [ 2019-02-16 07:28:18.937904 ] Epoch  58 batch   50/67 - Train accuracy: 0.3720, Validation accuracy: 0.4551, Loss: 1.5913
# [ 2019-02-16 07:28:56.753570 ] Epoch  59 batch   50/67 - Train accuracy: 0.4360, Validation accuracy: 0.4110, Loss: 1.5638
# [ 2019-02-16 07:29:34.689080 ] Epoch  60 batch   50/67 - Train accuracy: 0.4760, Validation accuracy: 0.4364, Loss: 1.5510
# [ 2019-02-16 07:30:12.486171 ] Epoch  61 batch   50/67 - Train accuracy: 0.3861, Validation accuracy: 0.4364, Loss: 1.5239
# [ 2019-02-16 07:30:50.267648 ] Epoch  62 batch   50/67 - Train accuracy: 0.2588, Validation accuracy: 0.3254, Loss: 1.4789
# [ 2019-02-16 07:31:28.205341 ] Epoch  63 batch   50/67 - Train accuracy: 0.3133, Validation accuracy: 0.2331, Loss: 1.5148
# [ 2019-02-16 07:32:06.013661 ] Epoch  64 batch   50/67 - Train accuracy: 0.3449, Validation accuracy: 0.2004, Loss: 1.4926
# [ 2019-02-16 07:32:43.887581 ] Epoch  65 batch   50/67 - Train accuracy: 0.3460, Validation accuracy: 0.2618, Loss: 1.4822
# [ 2019-02-16 07:33:21.738704 ] Epoch  66 batch   50/67 - Train accuracy: 0.4333, Validation accuracy: 0.3390, Loss: 1.4269
# [ 2019-02-16 07:33:59.581999 ] Epoch  67 batch   50/67 - Train accuracy: 0.3853, Validation accuracy: 0.4415, Loss: 1.4090
# [ 2019-02-16 07:34:37.487200 ] Epoch  68 batch   50/67 - Train accuracy: 0.3037, Validation accuracy: 0.3518, Loss: 1.3930
# [ 2019-02-16 07:35:15.323555 ] Epoch  69 batch   50/67 - Train accuracy: 0.2915, Validation accuracy: 0.2180, Loss: 1.3764
# [ 2019-02-16 07:35:53.107869 ] Epoch  70 batch   50/67 - Train accuracy: 0.1768, Validation accuracy: 0.2401, Loss: 1.3689
# [ 2019-02-16 07:36:31.088153 ] Epoch  71 batch   50/67 - Train accuracy: 0.2496, Validation accuracy: 0.2382, Loss: 1.3167
# [ 2019-02-16 07:37:08.898199 ] Epoch  72 batch   50/67 - Train accuracy: 0.2515, Validation accuracy: 0.2724, Loss: 1.3051
# [ 2019-02-16 07:37:46.768931 ] Epoch  73 batch   50/67 - Train accuracy: 0.2248, Validation accuracy: 0.1787, Loss: 1.2711
# [ 2019-02-16 07:38:24.670475 ] Epoch  74 batch   50/67 - Train accuracy: 0.2656, Validation accuracy: 0.2449, Loss: 1.2678
# [ 2019-02-16 07:39:02.637401 ] Epoch  75 batch   50/67 - Train accuracy: 0.3826, Validation accuracy: 0.3669, Loss: 1.2446
# [ 2019-02-16 07:39:40.491637 ] Epoch  76 batch   50/67 - Train accuracy: 0.3216, Validation accuracy: 0.3493, Loss: 1.2582
# [ 2019-02-16 07:40:18.373728 ] Epoch  77 batch   50/67 - Train accuracy: 0.4200, Validation accuracy: 0.3901, Loss: 1.2104
# [ 2019-02-16 07:40:56.212565 ] Epoch  78 batch   50/67 - Train accuracy: 0.4455, Validation accuracy: 0.3688, Loss: 1.1801
# [ 2019-02-16 07:41:34.198323 ] Epoch  79 batch   50/67 - Train accuracy: 0.3864, Validation accuracy: 0.3783, Loss: 1.1661
# [ 2019-02-16 07:42:12.092334 ] Epoch  80 batch   50/67 - Train accuracy: 0.3434, Validation accuracy: 0.3077, Loss: 1.1220
# [ 2019-02-16 07:42:49.900220 ] Epoch  81 batch   50/67 - Train accuracy: 0.2942, Validation accuracy: 0.3103, Loss: 1.0883
# [ 2019-02-16 07:43:27.804016 ] Epoch  82 batch   50/67 - Train accuracy: 0.2008, Validation accuracy: 0.2529, Loss: 1.1040
# [ 2019-02-16 07:44:05.726319 ] Epoch  83 batch   50/67 - Train accuracy: 0.3331, Validation accuracy: 0.2493, Loss: 1.0669
# [ 2019-02-16 07:44:43.706788 ] Epoch  84 batch   50/67 - Train accuracy: 0.3472, Validation accuracy: 0.3460, Loss: 1.0838
# [ 2019-02-16 07:45:21.580879 ] Epoch  85 batch   50/67 - Train accuracy: 0.3613, Validation accuracy: 0.3860, Loss: 1.0743
# [ 2019-02-16 07:45:59.422467 ] Epoch  86 batch   50/67 - Train accuracy: 0.3697, Validation accuracy: 0.3805, Loss: 1.0499
# [ 2019-02-16 07:46:37.458435 ] Epoch  87 batch   50/67 - Train accuracy: 0.2835, Validation accuracy: 0.3294, Loss: 1.0361
# [ 2019-02-16 07:47:15.371027 ] Epoch  88 batch   50/67 - Train accuracy: 0.3030, Validation accuracy: 0.2787, Loss: 1.0062
# [ 2019-02-16 07:47:53.241913 ] Epoch  89 batch   50/67 - Train accuracy: 0.3083, Validation accuracy: 0.3379, Loss: 1.0300
# [ 2019-02-16 07:48:31.157414 ] Epoch  90 batch   50/67 - Train accuracy: 0.3948, Validation accuracy: 0.3676, Loss: 1.0185
# [ 2019-02-16 07:49:09.069039 ] Epoch  91 batch   50/67 - Train accuracy: 0.4040, Validation accuracy: 0.3331, Loss: 1.0647
# [ 2019-02-16 07:49:47.144687 ] Epoch  92 batch   50/67 - Train accuracy: 0.4413, Validation accuracy: 0.4228, Loss: 1.0504
# [ 2019-02-16 07:50:24.952216 ] Epoch  93 batch   50/67 - Train accuracy: 0.3739, Validation accuracy: 0.4228, Loss: 1.0980
# [ 2019-02-16 07:51:02.803378 ] Epoch  94 batch   50/67 - Train accuracy: 0.4158, Validation accuracy: 0.3809, Loss: 0.9587
# [ 2019-02-16 07:51:40.715890 ] Epoch  95 batch   50/67 - Train accuracy: 0.3281, Validation accuracy: 0.3706, Loss: 0.9608
# [ 2019-02-16 07:52:18.694675 ] Epoch  96 batch   50/67 - Train accuracy: 0.3487, Validation accuracy: 0.3621, Loss: 0.9314
# [ 2019-02-16 07:52:56.566338 ] Epoch  97 batch   50/67 - Train accuracy: 0.3636, Validation accuracy: 0.3404, Loss: 0.8592
# [ 2019-02-16 07:53:34.397903 ] Epoch  98 batch   50/67 - Train accuracy: 0.3704, Validation accuracy: 0.3978, Loss: 0.8538
# [ 2019-02-16 07:54:12.183829 ] Epoch  99 batch   50/67 - Train accuracy: 0.3906, Validation accuracy: 0.3048, Loss: 0.8632
# [ 2019-02-16 07:54:50.093550 ] Epoch 100 batch   50/67 - Train accuracy: 0.4287, Validation accuracy: 0.3272, Loss: 0.8459
# [ 2019-02-16 07:55:27.949327 ] Epoch 101 batch   50/67 - Train accuracy: 0.4707, Validation accuracy: 0.4360, Loss: 0.8367
# [ 2019-02-16 07:56:05.827997 ] Epoch 102 batch   50/67 - Train accuracy: 0.3880, Validation accuracy: 0.3048, Loss: 0.8056
# [ 2019-02-16 07:56:43.742530 ] Epoch 103 batch   50/67 - Train accuracy: 0.4123, Validation accuracy: 0.3540, Loss: 0.8077
# [ 2019-02-16 07:57:21.764097 ] Epoch 104 batch   50/67 - Train accuracy: 0.3830, Validation accuracy: 0.3121, Loss: 0.7932
# [ 2019-02-16 07:57:59.589354 ] Epoch 105 batch   50/67 - Train accuracy: 0.4123, Validation accuracy: 0.3577, Loss: 0.7539
# [ 2019-02-16 07:58:37.543820 ] Epoch 106 batch   50/67 - Train accuracy: 0.3941, Validation accuracy: 0.2489, Loss: 0.7798
# [ 2019-02-16 07:59:15.458452 ] Epoch 107 batch   50/67 - Train accuracy: 0.4101, Validation accuracy: 0.2978, Loss: 0.7558
# [ 2019-02-16 07:59:53.427757 ] Epoch 108 batch   50/67 - Train accuracy: 0.4078, Validation accuracy: 0.2687, Loss: 0.7758
# [ 2019-02-16 08:00:31.279348 ] Epoch 109 batch   50/67 - Train accuracy: 0.4665, Validation accuracy: 0.2147, Loss: 0.7567
# [ 2019-02-16 08:01:09.242057 ] Epoch 110 batch   50/67 - Train accuracy: 0.4486, Validation accuracy: 0.2982, Loss: 0.7594
# [ 2019-02-16 08:01:47.159360 ] Epoch 111 batch   50/67 - Train accuracy: 0.4516, Validation accuracy: 0.3599, Loss: 0.7424
# [ 2019-02-16 08:02:25.205722 ] Epoch 112 batch   50/67 - Train accuracy: 0.4798, Validation accuracy: 0.3926, Loss: 0.7518
# [ 2019-02-16 08:03:03.068408 ] Epoch 113 batch   50/67 - Train accuracy: 0.4973, Validation accuracy: 0.4188, Loss: 0.7261
# [ 2019-02-16 08:03:40.949877 ] Epoch 114 batch   50/67 - Train accuracy: 0.4558, Validation accuracy: 0.3647, Loss: 0.7210
# [ 2019-02-16 08:04:18.759753 ] Epoch 115 batch   50/67 - Train accuracy: 0.3883, Validation accuracy: 0.2849, Loss: 0.6832
# [ 2019-02-16 08:04:56.737173 ] Epoch 116 batch   50/67 - Train accuracy: 0.3697, Validation accuracy: 0.2838, Loss: 0.6528
# [ 2019-02-16 08:05:34.625670 ] Epoch 117 batch   50/67 - Train accuracy: 0.3479, Validation accuracy: 0.1952, Loss: 0.6564
# [ 2019-02-16 08:06:12.555211 ] Epoch 118 batch   50/67 - Train accuracy: 0.3518, Validation accuracy: 0.2864, Loss: 0.6240
# [ 2019-02-16 08:06:50.475019 ] Epoch 119 batch   50/67 - Train accuracy: 0.4028, Validation accuracy: 0.2618, Loss: 0.6175
# [ 2019-02-16 08:07:28.444726 ] Epoch 120 batch   50/67 - Train accuracy: 0.4409, Validation accuracy: 0.2618, Loss: 0.6159
# [ 2019-02-16 08:08:06.380958 ] Epoch 121 batch   50/67 - Train accuracy: 0.4360, Validation accuracy: 0.3360, Loss: 0.5906
# [ 2019-02-16 08:08:44.305927 ] Epoch 122 batch   50/67 - Train accuracy: 0.4619, Validation accuracy: 0.3228, Loss: 0.5905
# [ 2019-02-16 08:09:22.195280 ] Epoch 123 batch   50/67 - Train accuracy: 0.4345, Validation accuracy: 0.3349, Loss: 0.5941
# [ 2019-02-16 08:10:00.162330 ] Epoch 124 batch   50/67 - Train accuracy: 0.4566, Validation accuracy: 0.3187, Loss: 0.5720
# [ 2019-02-16 08:10:38.053678 ] Epoch 125 batch   50/67 - Train accuracy: 0.4139, Validation accuracy: 0.3217, Loss: 0.5426
# [ 2019-02-16 08:11:16.026822 ] Epoch 126 batch   50/67 - Train accuracy: 0.4889, Validation accuracy: 0.3232, Loss: 0.5365
# [ 2019-02-16 08:11:53.969855 ] Epoch 127 batch   50/67 - Train accuracy: 0.4779, Validation accuracy: 0.2607, Loss: 0.5295
# [ 2019-02-16 08:12:32.039861 ] Epoch 128 batch   50/67 - Train accuracy: 0.4611, Validation accuracy: 0.3798, Loss: 0.5547
# [ 2019-02-16 08:13:09.930188 ] Epoch 129 batch   50/67 - Train accuracy: 0.4550, Validation accuracy: 0.3004, Loss: 0.5600
# [ 2019-02-16 08:13:47.787415 ] Epoch 130 batch   50/67 - Train accuracy: 0.4665, Validation accuracy: 0.3912, Loss: 0.5225
# [ 2019-02-16 08:14:25.637581 ] Epoch 131 batch   50/67 - Train accuracy: 0.4768, Validation accuracy: 0.3044, Loss: 0.5217
# [ 2019-02-16 08:15:03.511201 ] Epoch 132 batch   50/67 - Train accuracy: 0.4756, Validation accuracy: 0.3088, Loss: 0.4936
# [ 2019-02-16 08:15:41.322691 ] Epoch 133 batch   50/67 - Train accuracy: 0.4596, Validation accuracy: 0.2647, Loss: 0.5016
# [ 2019-02-16 08:16:19.188388 ] Epoch 134 batch   50/67 - Train accuracy: 0.4402, Validation accuracy: 0.2790, Loss: 0.4815
# [ 2019-02-16 08:16:57.044663 ] Epoch 135 batch   50/67 - Train accuracy: 0.4184, Validation accuracy: 0.2507, Loss: 0.4833
# [ 2019-02-16 08:17:34.990651 ] Epoch 136 batch   50/67 - Train accuracy: 0.4196, Validation accuracy: 0.3434, Loss: 0.4698
# [ 2019-02-16 08:18:12.919404 ] Epoch 137 batch   50/67 - Train accuracy: 0.4912, Validation accuracy: 0.2868, Loss: 0.4526
# [ 2019-02-16 08:18:50.787775 ] Epoch 138 batch   50/67 - Train accuracy: 0.4562, Validation accuracy: 0.2290, Loss: 0.4225
# [ 2019-02-16 08:19:28.645524 ] Epoch 139 batch   50/67 - Train accuracy: 0.4973, Validation accuracy: 0.3026, Loss: 0.4431
# [ 2019-02-16 08:20:06.555479 ] Epoch 140 batch   50/67 - Train accuracy: 0.4840, Validation accuracy: 0.2687, Loss: 0.4278
# [ 2019-02-16 08:20:44.463445 ] Epoch 141 batch   50/67 - Train accuracy: 0.5766, Validation accuracy: 0.2835, Loss: 0.4097
# [ 2019-02-16 08:21:22.344649 ] Epoch 142 batch   50/67 - Train accuracy: 0.5549, Validation accuracy: 0.3515, Loss: 0.4177
# [ 2019-02-16 08:22:00.223556 ] Epoch 143 batch   50/67 - Train accuracy: 0.5206, Validation accuracy: 0.3195, Loss: 0.4343
# [ 2019-02-16 08:22:38.119428 ] Epoch 144 batch   50/67 - Train accuracy: 0.5305, Validation accuracy: 0.3669, Loss: 0.4431
# [ 2019-02-16 08:23:16.062475 ] Epoch 145 batch   50/67 - Train accuracy: 0.5328, Validation accuracy: 0.3382, Loss: 0.4085
# [ 2019-02-16 08:23:53.957605 ] Epoch 146 batch   50/67 - Train accuracy: 0.5694, Validation accuracy: 0.3691, Loss: 0.3992
# [ 2019-02-16 08:24:31.893942 ] Epoch 147 batch   50/67 - Train accuracy: 0.5080, Validation accuracy: 0.3022, Loss: 0.3853
# [ 2019-02-16 08:25:09.870044 ] Epoch 148 batch   50/67 - Train accuracy: 0.5457, Validation accuracy: 0.4235, Loss: 0.4097
# [ 2019-02-16 08:25:47.764003 ] Epoch 149 batch   50/67 - Train accuracy: 0.5541, Validation accuracy: 0.3283, Loss: 0.3750
# [ 2019-02-16 08:26:25.627654 ] Epoch 150 batch   50/67 - Train accuracy: 0.5332, Validation accuracy: 0.3665, Loss: 0.3417
# [ 2019-02-16 08:27:03.540907 ] Epoch 151 batch   50/67 - Train accuracy: 0.5842, Validation accuracy: 0.3581, Loss: 0.3322
# [ 2019-02-16 08:27:41.466456 ] Epoch 152 batch   50/67 - Train accuracy: 0.6223, Validation accuracy: 0.3507, Loss: 0.3277
# [ 2019-02-16 08:28:19.465860 ] Epoch 153 batch   50/67 - Train accuracy: 0.5953, Validation accuracy: 0.3529, Loss: 0.3232
# [ 2019-02-16 08:28:57.415356 ] Epoch 154 batch   50/67 - Train accuracy: 0.5602, Validation accuracy: 0.2599, Loss: 0.3199
# [ 2019-02-16 08:29:35.368806 ] Epoch 155 batch   50/67 - Train accuracy: 0.5903, Validation accuracy: 0.3875, Loss: 0.3110
# [ 2019-02-16 08:30:13.427109 ] Epoch 156 batch   50/67 - Train accuracy: 0.5770, Validation accuracy: 0.3386, Loss: 0.3113
# [ 2019-02-16 08:30:51.298076 ] Epoch 157 batch   50/67 - Train accuracy: 0.6002, Validation accuracy: 0.3456, Loss: 0.3110
# [ 2019-02-16 08:31:29.229636 ] Epoch 158 batch   50/67 - Train accuracy: 0.5800, Validation accuracy: 0.3743, Loss: 0.3044
# [ 2019-02-16 08:32:07.234581 ] Epoch 159 batch   50/67 - Train accuracy: 0.5419, Validation accuracy: 0.3243, Loss: 0.3242
# [ 2019-02-16 08:32:45.211722 ] Epoch 160 batch   50/67 - Train accuracy: 0.5770, Validation accuracy: 0.3349, Loss: 0.3005
# [ 2019-02-16 08:33:23.225908 ] Epoch 161 batch   50/67 - Train accuracy: 0.6471, Validation accuracy: 0.3357, Loss: 0.2920
# [ 2019-02-16 08:34:01.097739 ] Epoch 162 batch   50/67 - Train accuracy: 0.6799, Validation accuracy: 0.3040, Loss: 0.2745
# [ 2019-02-16 08:34:38.997082 ] Epoch 163 batch   50/67 - Train accuracy: 0.6837, Validation accuracy: 0.3408, Loss: 0.2709
# [ 2019-02-16 08:35:17.030129 ] Epoch 164 batch   50/67 - Train accuracy: 0.5785, Validation accuracy: 0.3967, Loss: 0.2741
# [ 2019-02-16 08:35:54.913438 ] Epoch 165 batch   50/67 - Train accuracy: 0.6524, Validation accuracy: 0.3290, Loss: 0.2720
# [ 2019-02-16 08:36:32.816367 ] Epoch 166 batch   50/67 - Train accuracy: 0.6989, Validation accuracy: 0.2904, Loss: 0.2562
# [ 2019-02-16 08:37:10.776481 ] Epoch 167 batch   50/67 - Train accuracy: 0.6852, Validation accuracy: 0.3415, Loss: 0.2607
# [ 2019-02-16 08:37:48.796145 ] Epoch 168 batch   50/67 - Train accuracy: 0.6395, Validation accuracy: 0.4250, Loss: 0.2743
# [ 2019-02-16 08:38:26.852328 ] Epoch 169 batch   50/67 - Train accuracy: 0.6654, Validation accuracy: 0.3787, Loss: 0.2401
# [ 2019-02-16 08:39:04.767637 ] Epoch 170 batch   50/67 - Train accuracy: 0.6761, Validation accuracy: 0.3805, Loss: 0.2517
# [ 2019-02-16 08:39:42.687886 ] Epoch 171 batch   50/67 - Train accuracy: 0.7092, Validation accuracy: 0.3368, Loss: 0.2482
# [ 2019-02-16 08:40:20.755353 ] Epoch 172 batch   50/67 - Train accuracy: 0.6174, Validation accuracy: 0.3463, Loss: 0.2623
# [ 2019-02-16 08:40:58.694791 ] Epoch 173 batch   50/67 - Train accuracy: 0.6966, Validation accuracy: 0.3603, Loss: 0.2517
# [ 2019-02-16 08:41:36.569845 ] Epoch 174 batch   50/67 - Train accuracy: 0.6806, Validation accuracy: 0.3790, Loss: 0.2393
# [ 2019-02-16 08:42:14.513897 ] Epoch 175 batch   50/67 - Train accuracy: 0.6726, Validation accuracy: 0.3081, Loss: 0.2331
# [ 2019-02-16 08:42:52.365741 ] Epoch 176 batch   50/67 - Train accuracy: 0.7176, Validation accuracy: 0.3853, Loss: 0.2109
# [ 2019-02-16 08:43:30.286999 ] Epoch 177 batch   50/67 - Train accuracy: 0.7134, Validation accuracy: 0.3904, Loss: 0.2106
# [ 2019-02-16 08:44:08.132997 ] Epoch 178 batch   50/67 - Train accuracy: 0.7321, Validation accuracy: 0.3669, Loss: 0.2248
# [ 2019-02-16 08:44:45.950425 ] Epoch 179 batch   50/67 - Train accuracy: 0.7146, Validation accuracy: 0.3496, Loss: 0.2120
# [ 2019-02-16 08:45:23.991200 ] Epoch 180 batch   50/67 - Train accuracy: 0.7275, Validation accuracy: 0.3474, Loss: 0.2237
# [ 2019-02-16 08:46:01.941234 ] Epoch 181 batch   50/67 - Train accuracy: 0.7812, Validation accuracy: 0.3375, Loss: 0.2121
# [ 2019-02-16 08:46:39.913607 ] Epoch 182 batch   50/67 - Train accuracy: 0.7824, Validation accuracy: 0.3471, Loss: 0.1992
# [ 2019-02-16 08:47:17.784208 ] Epoch 183 batch   50/67 - Train accuracy: 0.7287, Validation accuracy: 0.3846, Loss: 0.2139
# [ 2019-02-16 08:47:55.771480 ] Epoch 184 batch   50/67 - Train accuracy: 0.8175, Validation accuracy: 0.3522, Loss: 0.1906
# [ 2019-02-16 08:48:33.747707 ] Epoch 185 batch   50/67 - Train accuracy: 0.7782, Validation accuracy: 0.3290, Loss: 0.1913
# [ 2019-02-16 08:49:11.747526 ] Epoch 186 batch   50/67 - Train accuracy: 0.7492, Validation accuracy: 0.4007, Loss: 0.1768
# [ 2019-02-16 08:49:49.695344 ] Epoch 187 batch   50/67 - Train accuracy: 0.8274, Validation accuracy: 0.3235, Loss: 0.1758
# [ 2019-02-16 08:50:27.598579 ] Epoch 188 batch   50/67 - Train accuracy: 0.7717, Validation accuracy: 0.3489, Loss: 0.1937
# [ 2019-02-16 08:51:05.599997 ] Epoch 189 batch   50/67 - Train accuracy: 0.7546, Validation accuracy: 0.3618, Loss: 0.2048
# [ 2019-02-16 08:51:43.504365 ] Epoch 190 batch   50/67 - Train accuracy: 0.7527, Validation accuracy: 0.3621, Loss: 0.1879
# [ 2019-02-16 08:52:21.412540 ] Epoch 191 batch   50/67 - Train accuracy: 0.7309, Validation accuracy: 0.3551, Loss: 0.1944
# [ 2019-02-16 08:52:59.322090 ] Epoch 192 batch   50/67 - Train accuracy: 0.8049, Validation accuracy: 0.3349, Loss: 0.1806
# [ 2019-02-16 08:53:37.143004 ] Epoch 193 batch   50/67 - Train accuracy: 0.7957, Validation accuracy: 0.4324, Loss: 0.2127
# [ 2019-02-16 08:54:15.110364 ] Epoch 194 batch   50/67 - Train accuracy: 0.7893, Validation accuracy: 0.3688, Loss: 0.2062
# [ 2019-02-16 08:54:53.066082 ] Epoch 195 batch   50/67 - Train accuracy: 0.8457, Validation accuracy: 0.3290, Loss: 0.1929
# [ 2019-02-16 08:55:30.971090 ] Epoch 196 batch   50/67 - Train accuracy: 0.7382, Validation accuracy: 0.3853, Loss: 0.1667
# [ 2019-02-16 08:56:09.003899 ] Epoch 197 batch   50/67 - Train accuracy: 0.8544, Validation accuracy: 0.3625, Loss: 0.1709
# [ 2019-02-16 08:56:46.888897 ] Epoch 198 batch   50/67 - Train accuracy: 0.8441, Validation accuracy: 0.3537, Loss: 0.1711
# [ 2019-02-16 08:57:24.845879 ] Epoch 199 batch   50/67 - Train accuracy: 0.8228, Validation accuracy: 0.3287, Loss: 0.1529
# [ 2019-02-16 08:58:02.796384 ] Epoch 200 batch   50/67 - Train accuracy: 0.8228, Validation accuracy: 0.3794, Loss: 0.1729
# [ 2019-02-16 08:58:40.811401 ] Epoch 201 batch   50/67 - Train accuracy: 0.8007, Validation accuracy: 0.2801, Loss: 0.1579
# [ 2019-02-16 08:59:18.805422 ] Epoch 202 batch   50/67 - Train accuracy: 0.8445, Validation accuracy: 0.3625, Loss: 0.1508
# [ 2019-02-16 08:59:56.811919 ] Epoch 203 batch   50/67 - Train accuracy: 0.8323, Validation accuracy: 0.3669, Loss: 0.1627
# [ 2019-02-16 09:00:34.711277 ] Epoch 204 batch   50/67 - Train accuracy: 0.8460, Validation accuracy: 0.3092, Loss: 0.1658
# [ 2019-02-16 09:01:12.668992 ] Epoch 205 batch   50/67 - Train accuracy: 0.8396, Validation accuracy: 0.3555, Loss: 0.1507
# [ 2019-02-16 09:01:50.491830 ] Epoch 206 batch   50/67 - Train accuracy: 0.8868, Validation accuracy: 0.2838, Loss: 0.1606
# [ 2019-02-16 09:02:28.368446 ] Epoch 207 batch   50/67 - Train accuracy: 0.8354, Validation accuracy: 0.3129, Loss: 0.1557
# [ 2019-02-16 09:03:06.314933 ] Epoch 208 batch   50/67 - Train accuracy: 0.8796, Validation accuracy: 0.2746, Loss: 0.1563
# [ 2019-02-16 09:03:44.203799 ] Epoch 209 batch   50/67 - Train accuracy: 0.8902, Validation accuracy: 0.2687, Loss: 0.1646
# [ 2019-02-16 09:04:22.200738 ] Epoch 210 batch   50/67 - Train accuracy: 0.8876, Validation accuracy: 0.2537, Loss: 0.1661
# [ 2019-02-16 09:05:00.126744 ] Epoch 211 batch   50/67 - Train accuracy: 0.8563, Validation accuracy: 0.3298, Loss: 0.1394
# [ 2019-02-16 09:05:38.028033 ] Epoch 212 batch   50/67 - Train accuracy: 0.8693, Validation accuracy: 0.2607, Loss: 0.1390
# [ 2019-02-16 09:06:16.009024 ] Epoch 213 batch   50/67 - Train accuracy: 0.9017, Validation accuracy: 0.3040, Loss: 0.1406
# [ 2019-02-16 09:06:53.861947 ] Epoch 214 batch   50/67 - Train accuracy: 0.8216, Validation accuracy: 0.2404, Loss: 0.1247
# [ 2019-02-16 09:07:31.720900 ] Epoch 215 batch   50/67 - Train accuracy: 0.8624, Validation accuracy: 0.3228, Loss: 0.1305
# [ 2019-02-16 09:08:09.621105 ] Epoch 216 batch   50/67 - Train accuracy: 0.8788, Validation accuracy: 0.3085, Loss: 0.1462
# [ 2019-02-16 09:08:47.615720 ] Epoch 217 batch   50/67 - Train accuracy: 0.8807, Validation accuracy: 0.3040, Loss: 0.1394
# [ 2019-02-16 09:09:25.690357 ] Epoch 218 batch   50/67 - Train accuracy: 0.9226, Validation accuracy: 0.3191, Loss: 0.1239
# [ 2019-02-16 09:10:03.559627 ] Epoch 219 batch   50/67 - Train accuracy: 0.8346, Validation accuracy: 0.3081, Loss: 0.1249
# [ 2019-02-16 09:10:41.493081 ] Epoch 220 batch   50/67 - Train accuracy: 0.9127, Validation accuracy: 0.2669, Loss: 0.1244
# [ 2019-02-16 09:11:19.567842 ] Epoch 221 batch   50/67 - Train accuracy: 0.8883, Validation accuracy: 0.2596, Loss: 0.1352
# [ 2019-02-16 09:11:57.500442 ] Epoch 222 batch   50/67 - Train accuracy: 0.8716, Validation accuracy: 0.2890, Loss: 0.1252
# [ 2019-02-16 09:12:35.444598 ] Epoch 223 batch   50/67 - Train accuracy: 0.8750, Validation accuracy: 0.2875, Loss: 0.1286
# [ 2019-02-16 09:13:13.444426 ] Epoch 224 batch   50/67 - Train accuracy: 0.9062, Validation accuracy: 0.2871, Loss: 0.1188
# [ 2019-02-16 09:13:51.491031 ] Epoch 225 batch   50/67 - Train accuracy: 0.9425, Validation accuracy: 0.2566, Loss: 0.1181
# [ 2019-02-16 09:14:29.499794 ] Epoch 226 batch   50/67 - Train accuracy: 0.9508, Validation accuracy: 0.2529, Loss: 0.1311
# [ 2019-02-16 09:15:07.477375 ] Epoch 227 batch   50/67 - Train accuracy: 0.8769, Validation accuracy: 0.3246, Loss: 0.1218
# [ 2019-02-16 09:15:45.391518 ] Epoch 228 batch   50/67 - Train accuracy: 0.9150, Validation accuracy: 0.2702, Loss: 0.1205
# [ 2019-02-16 09:16:23.387608 ] Epoch 229 batch   50/67 - Train accuracy: 0.8518, Validation accuracy: 0.2379, Loss: 0.1153
# [ 2019-02-16 09:17:01.140792 ] Epoch 230 batch   50/67 - Train accuracy: 0.9402, Validation accuracy: 0.2261, Loss: 0.1399
# [ 2019-02-16 09:17:38.992018 ] Epoch 231 batch   50/67 - Train accuracy: 0.9150, Validation accuracy: 0.3540, Loss: 0.1102
# [ 2019-02-16 09:18:16.877518 ] Epoch 232 batch   50/67 - Train accuracy: 0.9291, Validation accuracy: 0.2772, Loss: 0.1094
# [ 2019-02-16 09:18:54.747968 ] Epoch 233 batch   50/67 - Train accuracy: 0.9451, Validation accuracy: 0.2754, Loss: 0.1074
# [ 2019-02-16 09:19:32.632311 ] Epoch 234 batch   50/67 - Train accuracy: 0.9405, Validation accuracy: 0.2621, Loss: 0.1093
# [ 2019-02-16 09:20:10.653797 ] Epoch 235 batch   50/67 - Train accuracy: 0.9264, Validation accuracy: 0.2496, Loss: 0.1034
# [ 2019-02-16 09:20:48.531148 ] Epoch 236 batch   50/67 - Train accuracy: 0.8895, Validation accuracy: 0.3015, Loss: 0.1124
# [ 2019-02-16 09:21:26.537427 ] Epoch 237 batch   50/67 - Train accuracy: 0.8750, Validation accuracy: 0.2313, Loss: 0.0987
# [ 2019-02-16 09:22:04.514771 ] Epoch 238 batch   50/67 - Train accuracy: 0.9348, Validation accuracy: 0.3004, Loss: 0.1077
# [ 2019-02-16 09:22:42.391052 ] Epoch 239 batch   50/67 - Train accuracy: 0.9257, Validation accuracy: 0.3338, Loss: 0.0999
# [ 2019-02-16 09:23:20.180135 ] Epoch 240 batch   50/67 - Train accuracy: 0.9089, Validation accuracy: 0.2706, Loss: 0.1014
# [ 2019-02-16 09:23:58.042706 ] Epoch 241 batch   50/67 - Train accuracy: 0.9398, Validation accuracy: 0.2658, Loss: 0.0982
# [ 2019-02-16 09:24:35.853328 ] Epoch 242 batch   50/67 - Train accuracy: 0.9592, Validation accuracy: 0.3070, Loss: 0.1113
# [ 2019-02-16 09:25:13.715300 ] Epoch 243 batch   50/67 - Train accuracy: 0.9447, Validation accuracy: 0.2824, Loss: 0.0942
# [ 2019-02-16 09:25:51.630811 ] Epoch 244 batch   50/67 - Train accuracy: 0.9562, Validation accuracy: 0.2210, Loss: 0.1143
# [ 2019-02-16 09:26:29.565530 ] Epoch 245 batch   50/67 - Train accuracy: 0.9577, Validation accuracy: 0.2750, Loss: 0.0915
# [ 2019-02-16 09:27:07.472125 ] Epoch 246 batch   50/67 - Train accuracy: 0.9013, Validation accuracy: 0.2324, Loss: 0.0943
# [ 2019-02-16 09:27:45.301663 ] Epoch 247 batch   50/67 - Train accuracy: 0.9207, Validation accuracy: 0.2614, Loss: 0.0988
# [ 2019-02-16 09:28:23.133984 ] Epoch 248 batch   50/67 - Train accuracy: 0.9337, Validation accuracy: 0.2978, Loss: 0.0959
# [ 2019-02-16 09:29:01.019584 ] Epoch 249 batch   50/67 - Train accuracy: 0.9261, Validation accuracy: 0.2827, Loss: 0.0983
# [ 2019-02-16 09:29:38.974931 ] Epoch 250 batch   50/67 - Train accuracy: 0.9257, Validation accuracy: 0.3320, Loss: 0.0914
# [ 2019-02-16 09:30:16.982834 ] Epoch 251 batch   50/67 - Train accuracy: 0.9219, Validation accuracy: 0.2562, Loss: 0.0878
# [ 2019-02-16 09:30:54.829758 ] Epoch 252 batch   50/67 - Train accuracy: 0.9211, Validation accuracy: 0.2268, Loss: 0.0943
# [ 2019-02-16 09:31:32.758335 ] Epoch 253 batch   50/67 - Train accuracy: 0.9306, Validation accuracy: 0.2393, Loss: 0.0821
# [ 2019-02-16 09:32:10.646581 ] Epoch 254 batch   50/67 - Train accuracy: 0.9196, Validation accuracy: 0.3239, Loss: 0.0826
# [ 2019-02-16 09:32:48.549972 ] Epoch 255 batch   50/67 - Train accuracy: 0.9165, Validation accuracy: 0.2827, Loss: 0.0902
# [ 2019-02-16 09:33:26.489627 ] Epoch 256 batch   50/67 - Train accuracy: 0.9390, Validation accuracy: 0.2485, Loss: 0.0829
# [ 2019-02-16 09:34:04.407923 ] Epoch 257 batch   50/67 - Train accuracy: 0.9444, Validation accuracy: 0.2798, Loss: 0.0855
# [ 2019-02-16 09:34:42.357348 ] Epoch 258 batch   50/67 - Train accuracy: 0.9165, Validation accuracy: 0.3026, Loss: 0.0795
# [ 2019-02-16 09:35:20.448028 ] Epoch 259 batch   50/67 - Train accuracy: 0.9413, Validation accuracy: 0.2445, Loss: 0.0866
# [ 2019-02-16 09:35:58.431736 ] Epoch 260 batch   50/67 - Train accuracy: 0.9512, Validation accuracy: 0.2614, Loss: 0.0859
# [ 2019-02-16 09:36:36.426470 ] Epoch 261 batch   50/67 - Train accuracy: 0.9413, Validation accuracy: 0.2559, Loss: 0.0929
# [ 2019-02-16 09:37:14.376590 ] Epoch 262 batch   50/67 - Train accuracy: 0.9200, Validation accuracy: 0.2015, Loss: 0.0790
# [ 2019-02-16 09:37:52.361601 ] Epoch 263 batch   50/67 - Train accuracy: 0.9588, Validation accuracy: 0.3287, Loss: 0.0792
# [ 2019-02-16 09:38:30.255276 ] Epoch 264 batch   50/67 - Train accuracy: 0.9973, Validation accuracy: 0.2254, Loss: 0.0774
# [ 2019-02-16 09:39:08.118647 ] Epoch 265 batch   50/67 - Train accuracy: 0.9607, Validation accuracy: 0.3210, Loss: 0.0855
# [ 2019-02-16 09:39:45.988773 ] Epoch 266 batch   50/67 - Train accuracy: 0.9314, Validation accuracy: 0.2941, Loss: 0.0989
# [ 2019-02-16 09:40:24.053534 ] Epoch 267 batch   50/67 - Train accuracy: 0.9162, Validation accuracy: 0.3051, Loss: 0.0844
# [ 2019-02-16 09:41:01.993179 ] Epoch 268 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.2482, Loss: 0.0791
# [ 2019-02-16 09:41:40.031202 ] Epoch 269 batch   50/67 - Train accuracy: 0.9611, Validation accuracy: 0.2805, Loss: 0.0763
# [ 2019-02-16 09:42:17.972957 ] Epoch 270 batch   50/67 - Train accuracy: 0.9691, Validation accuracy: 0.3048, Loss: 0.0709
# [ 2019-02-16 09:42:55.913485 ] Epoch 271 batch   50/67 - Train accuracy: 0.9352, Validation accuracy: 0.2787, Loss: 0.0723
# [ 2019-02-16 09:43:33.771000 ] Epoch 272 batch   50/67 - Train accuracy: 0.9657, Validation accuracy: 0.2746, Loss: 0.0921
# [ 2019-02-16 09:44:11.684973 ] Epoch 273 batch   50/67 - Train accuracy: 0.9558, Validation accuracy: 0.2610, Loss: 0.0910
# [ 2019-02-16 09:44:49.684768 ] Epoch 274 batch   50/67 - Train accuracy: 0.9775, Validation accuracy: 0.2397, Loss: 0.0937
# [ 2019-02-16 09:45:27.698948 ] Epoch 275 batch   50/67 - Train accuracy: 0.9478, Validation accuracy: 0.2801, Loss: 0.0900
# [ 2019-02-16 09:46:05.740202 ] Epoch 276 batch   50/67 - Train accuracy: 0.9318, Validation accuracy: 0.3018, Loss: 0.0765
# [ 2019-02-16 09:46:43.741842 ] Epoch 277 batch   50/67 - Train accuracy: 0.9440, Validation accuracy: 0.2724, Loss: 0.0799
# [ 2019-02-16 09:47:21.624815 ] Epoch 278 batch   50/67 - Train accuracy: 0.9535, Validation accuracy: 0.3647, Loss: 0.0781
# [ 2019-02-16 09:47:59.552962 ] Epoch 279 batch   50/67 - Train accuracy: 0.9211, Validation accuracy: 0.2482, Loss: 0.0676
# [ 2019-02-16 09:48:37.459038 ] Epoch 280 batch   50/67 - Train accuracy: 0.9985, Validation accuracy: 0.2022, Loss: 0.0753
# [ 2019-02-16 09:49:15.276868 ] Epoch 281 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.3074, Loss: 0.0828
# [ 2019-02-16 09:49:53.237344 ] Epoch 282 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.2926, Loss: 0.0728
# [ 2019-02-16 09:50:31.122682 ] Epoch 283 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.2331, Loss: 0.0677
# [ 2019-02-16 09:51:09.068945 ] Epoch 284 batch   50/67 - Train accuracy: 0.9806, Validation accuracy: 0.2680, Loss: 0.0596
# [ 2019-02-16 09:51:47.037883 ] Epoch 285 batch   50/67 - Train accuracy: 0.9848, Validation accuracy: 0.3169, Loss: 0.0768
# [ 2019-02-16 09:52:24.968150 ] Epoch 286 batch   50/67 - Train accuracy: 0.9950, Validation accuracy: 0.3426, Loss: 0.0705
# [ 2019-02-16 09:53:02.943633 ] Epoch 287 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.2779, Loss: 0.0739
# [ 2019-02-16 09:53:40.853728 ] Epoch 288 batch   50/67 - Train accuracy: 0.9466, Validation accuracy: 0.3173, Loss: 0.0789
# [ 2019-02-16 09:54:18.910668 ] Epoch 289 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.2574, Loss: 0.0812
# [ 2019-02-16 09:54:56.864557 ] Epoch 290 batch   50/67 - Train accuracy: 0.9821, Validation accuracy: 0.3165, Loss: 0.0638
# [ 2019-02-16 09:55:34.776227 ] Epoch 291 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.2393, Loss: 0.0646
# [ 2019-02-16 09:56:12.843140 ] Epoch 292 batch   50/67 - Train accuracy: 0.9848, Validation accuracy: 0.2577, Loss: 0.0758
# [ 2019-02-16 09:56:50.971070 ] Epoch 293 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.2849, Loss: 0.0659
# [ 2019-02-16 09:57:28.896991 ] Epoch 294 batch   50/67 - Train accuracy: 0.9821, Validation accuracy: 0.2724, Loss: 0.0671
# [ 2019-02-16 09:58:06.812664 ] Epoch 295 batch   50/67 - Train accuracy: 0.9787, Validation accuracy: 0.2956, Loss: 0.0770
# [ 2019-02-16 09:58:44.699156 ] Epoch 296 batch   50/67 - Train accuracy: 0.9916, Validation accuracy: 0.2357, Loss: 0.0574
# [ 2019-02-16 09:59:22.509581 ] Epoch 297 batch   50/67 - Train accuracy: 0.9848, Validation accuracy: 0.2739, Loss: 0.0528
# [ 2019-02-16 10:00:00.413054 ] Epoch 298 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.2669, Loss: 0.0580
# [ 2019-02-16 10:00:38.263626 ] Epoch 299 batch   50/67 - Train accuracy: 0.9440, Validation accuracy: 0.2493, Loss: 0.0634
# [ 2019-02-16 10:01:16.190804 ] Epoch 300 batch   50/67 - Train accuracy: 0.9790, Validation accuracy: 0.2570, Loss: 0.0674
# [ 2019-02-16 10:01:54.169687 ] Epoch 301 batch   50/67 - Train accuracy: 0.9931, Validation accuracy: 0.2728, Loss: 0.0572
# [ 2019-02-16 10:02:32.060194 ] Epoch 302 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.2805, Loss: 0.0523
# [ 2019-02-16 10:03:09.895087 ] Epoch 303 batch   50/67 - Train accuracy: 0.9996, Validation accuracy: 0.3033, Loss: 0.0707
# [ 2019-02-16 10:03:47.770410 ] Epoch 304 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.3140, Loss: 0.0677
# [ 2019-02-16 10:04:25.684421 ] Epoch 305 batch   50/67 - Train accuracy: 0.9836, Validation accuracy: 0.2629, Loss: 0.0753
# [ 2019-02-16 10:05:03.503476 ] Epoch 306 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.3195, Loss: 0.0509
# [ 2019-02-16 10:05:41.373681 ] Epoch 307 batch   50/67 - Train accuracy: 0.9958, Validation accuracy: 0.2449, Loss: 0.0818
# [ 2019-02-16 10:06:19.388971 ] Epoch 308 batch   50/67 - Train accuracy: 0.9905, Validation accuracy: 0.2522, Loss: 0.0687
# [ 2019-02-16 10:06:57.387369 ] Epoch 309 batch   50/67 - Train accuracy: 0.9878, Validation accuracy: 0.3195, Loss: 0.0712
# [ 2019-02-16 10:07:35.249747 ] Epoch 310 batch   50/67 - Train accuracy: 0.9867, Validation accuracy: 0.2511, Loss: 0.0653
# [ 2019-02-16 10:08:13.108323 ] Epoch 311 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.2967, Loss: 0.0588
# [ 2019-02-16 10:08:50.978516 ] Epoch 312 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.2805, Loss: 0.0667
# [ 2019-02-16 10:09:28.888449 ] Epoch 313 batch   50/67 - Train accuracy: 0.9588, Validation accuracy: 0.2669, Loss: 0.0589
# [ 2019-02-16 10:10:06.740150 ] Epoch 314 batch   50/67 - Train accuracy: 0.9992, Validation accuracy: 0.3070, Loss: 0.0585
# [ 2019-02-16 10:10:44.598279 ] Epoch 315 batch   50/67 - Train accuracy: 0.9714, Validation accuracy: 0.2827, Loss: 0.0561
# [ 2019-02-16 10:11:22.531912 ] Epoch 316 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.3404, Loss: 0.0492
# [ 2019-02-16 10:12:00.590533 ] Epoch 317 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.2728, Loss: 0.0538
# [ 2019-02-16 10:12:38.579185 ] Epoch 318 batch   50/67 - Train accuracy: 0.9806, Validation accuracy: 0.2305, Loss: 0.0559
# [ 2019-02-16 10:13:16.438150 ] Epoch 319 batch   50/67 - Train accuracy: 0.9996, Validation accuracy: 0.3007, Loss: 0.0572
# [ 2019-02-16 10:13:54.251051 ] Epoch 320 batch   50/67 - Train accuracy: 0.9863, Validation accuracy: 0.2849, Loss: 0.0700
# [ 2019-02-16 10:14:32.134878 ] Epoch 321 batch   50/67 - Train accuracy: 0.9688, Validation accuracy: 0.2544, Loss: 0.0526
# [ 2019-02-16 10:15:10.073831 ] Epoch 322 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.3265, Loss: 0.0496
# [ 2019-02-16 10:15:47.873925 ] Epoch 323 batch   50/67 - Train accuracy: 0.9802, Validation accuracy: 0.2835, Loss: 0.0539
# [ 2019-02-16 10:16:25.790732 ] Epoch 324 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.3831, Loss: 0.0482
# [ 2019-02-16 10:17:03.826180 ] Epoch 325 batch   50/67 - Train accuracy: 0.9970, Validation accuracy: 0.2757, Loss: 0.0517
# [ 2019-02-16 10:17:41.757968 ] Epoch 326 batch   50/67 - Train accuracy: 0.9829, Validation accuracy: 0.3324, Loss: 0.0582
# [ 2019-02-16 10:18:19.661982 ] Epoch 327 batch   50/67 - Train accuracy: 0.9832, Validation accuracy: 0.2908, Loss: 0.0595
# [ 2019-02-16 10:18:57.469721 ] Epoch 328 batch   50/67 - Train accuracy: 0.9729, Validation accuracy: 0.2754, Loss: 0.0666
# [ 2019-02-16 10:19:35.310381 ] Epoch 329 batch   50/67 - Train accuracy: 0.9851, Validation accuracy: 0.2779, Loss: 0.0775
# [ 2019-02-16 10:20:13.200796 ] Epoch 330 batch   50/67 - Train accuracy: 0.9996, Validation accuracy: 0.3191, Loss: 0.0555
# [ 2019-02-16 10:20:51.118784 ] Epoch 331 batch   50/67 - Train accuracy: 0.9996, Validation accuracy: 0.2294, Loss: 0.0705
# [ 2019-02-16 10:21:28.935509 ] Epoch 332 batch   50/67 - Train accuracy: 0.9905, Validation accuracy: 0.2915, Loss: 0.0569
# [ 2019-02-16 10:22:06.945537 ] Epoch 333 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.3540, Loss: 0.0596
# [ 2019-02-16 10:22:44.870889 ] Epoch 334 batch   50/67 - Train accuracy: 0.9912, Validation accuracy: 0.2640, Loss: 0.0431
# [ 2019-02-16 10:23:22.712189 ] Epoch 335 batch   50/67 - Train accuracy: 0.9996, Validation accuracy: 0.2665, Loss: 0.0488
# [ 2019-02-16 10:24:00.466046 ] Epoch 336 batch   50/67 - Train accuracy: 0.9798, Validation accuracy: 0.2960, Loss: 0.0496
# [ 2019-02-16 10:24:38.283874 ] Epoch 337 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.2820, Loss: 0.0605
# [ 2019-02-16 10:25:16.073076 ] Epoch 338 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.2651, Loss: 0.0438
# [ 2019-02-16 10:25:53.934856 ] Epoch 339 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.2581, Loss: 0.0543
# [ 2019-02-16 10:26:31.778011 ] Epoch 340 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.3294, Loss: 0.0453
# [ 2019-02-16 10:27:09.761688 ] Epoch 341 batch   50/67 - Train accuracy: 0.9924, Validation accuracy: 0.3000, Loss: 0.0581
# [ 2019-02-16 10:27:47.755444 ] Epoch 342 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.3210, Loss: 0.0495
# [ 2019-02-16 10:28:25.592991 ] Epoch 343 batch   50/67 - Train accuracy: 0.9973, Validation accuracy: 0.3496, Loss: 0.0496
# [ 2019-02-16 10:29:03.448045 ] Epoch 344 batch   50/67 - Train accuracy: 0.9703, Validation accuracy: 0.2555, Loss: 0.0404
# [ 2019-02-16 10:29:41.390049 ] Epoch 345 batch   50/67 - Train accuracy: 0.9695, Validation accuracy: 0.3235, Loss: 0.0564
# [ 2019-02-16 10:30:19.152374 ] Epoch 346 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.2143, Loss: 0.0439
# [ 2019-02-16 10:30:56.922055 ] Epoch 347 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.2397, Loss: 0.0565
# [ 2019-02-16 10:31:34.700220 ] Epoch 348 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.2566, Loss: 0.0569
# [ 2019-02-16 10:32:12.707492 ] Epoch 349 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.3173, Loss: 0.0445
# [ 2019-02-16 10:32:50.718698 ] Epoch 350 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.2831, Loss: 0.0393
# [ 2019-02-16 10:33:28.655337 ] Epoch 351 batch   50/67 - Train accuracy: 0.9996, Validation accuracy: 0.3029, Loss: 0.0451
# [ 2019-02-16 10:34:06.502526 ] Epoch 352 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.2824, Loss: 0.0517
# [ 2019-02-16 10:34:44.373497 ] Epoch 353 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.3074, Loss: 0.0353
# [ 2019-02-16 10:35:22.289514 ] Epoch 354 batch   50/67 - Train accuracy: 0.9916, Validation accuracy: 0.3688, Loss: 0.0498
# [ 2019-02-16 10:36:00.186804 ] Epoch 355 batch   50/67 - Train accuracy: 0.9863, Validation accuracy: 0.2401, Loss: 0.0611
# [ 2019-02-16 10:36:38.016000 ] Epoch 356 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.2860, Loss: 0.0405
# [ 2019-02-16 10:37:16.109146 ] Epoch 357 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.3000, Loss: 0.0476
# [ 2019-02-16 10:37:54.059189 ] Epoch 358 batch   50/67 - Train accuracy: 0.9760, Validation accuracy: 0.2603, Loss: 0.0495
# [ 2019-02-16 10:38:31.952583 ] Epoch 359 batch   50/67 - Train accuracy: 0.9992, Validation accuracy: 0.2603, Loss: 0.0542
# [ 2019-02-16 10:39:09.893599 ] Epoch 360 batch   50/67 - Train accuracy: 0.9878, Validation accuracy: 0.3015, Loss: 0.0476
# [ 2019-02-16 10:39:47.741487 ] Epoch 361 batch   50/67 - Train accuracy: 0.9829, Validation accuracy: 0.2574, Loss: 0.0468
# [ 2019-02-16 10:40:25.569668 ] Epoch 362 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.2673, Loss: 0.0494
# [ 2019-02-16 10:41:03.491584 ] Epoch 363 batch   50/67 - Train accuracy: 0.9901, Validation accuracy: 0.3000, Loss: 0.0434
# [ 2019-02-16 10:41:41.394574 ] Epoch 364 batch   50/67 - Train accuracy: 0.9878, Validation accuracy: 0.2279, Loss: 0.0453
# [ 2019-02-16 10:42:19.247907 ] Epoch 365 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.3096, Loss: 0.0472
# [ 2019-02-16 10:42:57.263881 ] Epoch 366 batch   50/67 - Train accuracy: 0.9787, Validation accuracy: 0.3092, Loss: 0.0553
# [ 2019-02-16 10:43:35.185511 ] Epoch 367 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.3217, Loss: 0.0457
# [ 2019-02-16 10:44:13.174508 ] Epoch 368 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.3169, Loss: 0.0490
# [ 2019-02-16 10:44:51.083231 ] Epoch 369 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.3702, Loss: 0.0428
# [ 2019-02-16 10:45:28.923490 ] Epoch 370 batch   50/67 - Train accuracy: 0.9771, Validation accuracy: 0.2882, Loss: 0.0512
# [ 2019-02-16 10:46:06.829069 ] Epoch 371 batch   50/67 - Train accuracy: 0.9912, Validation accuracy: 0.3445, Loss: 0.0454
# [ 2019-02-16 10:46:44.774762 ] Epoch 372 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.2915, Loss: 0.0515
# [ 2019-02-16 10:47:22.703064 ] Epoch 373 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.2632, Loss: 0.0582
# [ 2019-02-16 10:48:00.743616 ] Epoch 374 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.2375, Loss: 0.0502
# [ 2019-02-16 10:48:38.624878 ] Epoch 375 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.2794, Loss: 0.0430
# [ 2019-02-16 10:49:16.535962 ] Epoch 376 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.3015, Loss: 0.0432
# [ 2019-02-16 10:49:54.412427 ] Epoch 377 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.2967, Loss: 0.0481
# [ 2019-02-16 10:50:32.232336 ] Epoch 378 batch   50/67 - Train accuracy: 0.9889, Validation accuracy: 0.3007, Loss: 0.0485
# [ 2019-02-16 10:51:10.076130 ] Epoch 379 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.2544, Loss: 0.0376
# [ 2019-02-16 10:51:47.987677 ] Epoch 380 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.2478, Loss: 0.0401
# [ 2019-02-16 10:52:25.829017 ] Epoch 381 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.3011, Loss: 0.0352
# [ 2019-02-16 10:53:03.813890 ] Epoch 382 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.2529, Loss: 0.0376
# [ 2019-02-16 10:53:41.734223 ] Epoch 383 batch   50/67 - Train accuracy: 0.9996, Validation accuracy: 0.3467, Loss: 0.0386
# [ 2019-02-16 10:54:19.624410 ] Epoch 384 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.3636, Loss: 0.0467
# [ 2019-02-16 10:54:57.512781 ] Epoch 385 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.3438, Loss: 0.0364
# [ 2019-02-16 10:55:35.453866 ] Epoch 386 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.3004, Loss: 0.0552
# [ 2019-02-16 10:56:13.322926 ] Epoch 387 batch   50/67 - Train accuracy: 0.9897, Validation accuracy: 0.2610, Loss: 0.0493
# [ 2019-02-16 10:56:51.199193 ] Epoch 388 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.3033, Loss: 0.0458
# [ 2019-02-16 10:57:29.074977 ] Epoch 389 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.2949, Loss: 0.0397
# [ 2019-02-16 10:58:07.080304 ] Epoch 390 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.2651, Loss: 0.0344
# [ 2019-02-16 10:58:44.960863 ] Epoch 391 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.3004, Loss: 0.0439
# [ 2019-02-16 10:59:22.809180 ] Epoch 392 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.3312, Loss: 0.0393
# [ 2019-02-16 11:00:00.650874 ] Epoch 393 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.2629, Loss: 0.0459
# [ 2019-02-16 11:00:38.460156 ] Epoch 394 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.3074, Loss: 0.0436
# [ 2019-02-16 11:01:16.430551 ] Epoch 395 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.3790, Loss: 0.0454
# [ 2019-02-16 11:01:54.356049 ] Epoch 396 batch   50/67 - Train accuracy: 0.9760, Validation accuracy: 0.2982, Loss: 0.0395
# [ 2019-02-16 11:02:32.143986 ] Epoch 397 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.3353, Loss: 0.0494
# [ 2019-02-16 11:03:10.262450 ] Epoch 398 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.3423, Loss: 0.0409
# [ 2019-02-16 11:03:48.190422 ] Epoch 399 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.2827, Loss: 0.0379
# [ 2019-02-16 11:04:26.110655 ] Epoch 400 batch   50/67 - Train accuracy: 0.9748, Validation accuracy: 0.3853, Loss: 0.0461
# [ 2019-02-16 11:05:03.948690 ] Epoch 401 batch   50/67 - Train accuracy: 0.9863, Validation accuracy: 0.3603, Loss: 0.0431
# [ 2019-02-16 11:05:41.783465 ] Epoch 402 batch   50/67 - Train accuracy: 0.9737, Validation accuracy: 0.2960, Loss: 0.0428
# [ 2019-02-16 11:06:19.708650 ] Epoch 403 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.2790, Loss: 0.0444
# [ 2019-02-16 11:06:57.616872 ] Epoch 404 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.2860, Loss: 0.0364
# [ 2019-02-16 11:07:35.461947 ] Epoch 405 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.3143, Loss: 0.0380
# [ 2019-02-16 11:08:13.431946 ] Epoch 406 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.3000, Loss: 0.0576
# [ 2019-02-16 11:08:51.443593 ] Epoch 407 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.4085, Loss: 0.0590
# [ 2019-02-16 11:09:29.358640 ] Epoch 408 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.2857, Loss: 0.0506
# [ 2019-02-16 11:10:07.175050 ] Epoch 409 batch   50/67 - Train accuracy: 0.9691, Validation accuracy: 0.3713, Loss: 0.0378
# [ 2019-02-16 11:10:45.102638 ] Epoch 410 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.2235, Loss: 0.0399
# [ 2019-02-16 11:11:22.968457 ] Epoch 411 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.3121, Loss: 0.0456
# [ 2019-02-16 11:12:00.835340 ] Epoch 412 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.2515, Loss: 0.0400
# [ 2019-02-16 11:12:38.825654 ] Epoch 413 batch   50/67 - Train accuracy: 0.9790, Validation accuracy: 0.3007, Loss: 0.0479
# [ 2019-02-16 11:13:16.792675 ] Epoch 414 batch   50/67 - Train accuracy: 0.9790, Validation accuracy: 0.3393, Loss: 0.0526
# [ 2019-02-16 11:13:54.763992 ] Epoch 415 batch   50/67 - Train accuracy: 0.9859, Validation accuracy: 0.2871, Loss: 0.0442
# [ 2019-02-16 11:14:32.575319 ] Epoch 416 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.2746, Loss: 0.0533
# [ 2019-02-16 11:15:10.523406 ] Epoch 417 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.2908, Loss: 0.0384
# [ 2019-02-16 11:15:48.429946 ] Epoch 418 batch   50/67 - Train accuracy: 0.9985, Validation accuracy: 0.2647, Loss: 0.0496
# [ 2019-02-16 11:16:26.411357 ] Epoch 419 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.3180, Loss: 0.0524
# [ 2019-02-16 11:17:04.372042 ] Epoch 420 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.2790, Loss: 0.0440
# [ 2019-02-16 11:17:42.281970 ] Epoch 421 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.2801, Loss: 0.0308
# [ 2019-02-16 11:18:20.202034 ] Epoch 422 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.3202, Loss: 0.0340
# [ 2019-02-16 11:18:58.252461 ] Epoch 423 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.3254, Loss: 0.0509
# [ 2019-02-16 11:19:36.118948 ] Epoch 424 batch   50/67 - Train accuracy: 0.9924, Validation accuracy: 0.3132, Loss: 0.0404
# [ 2019-02-16 11:20:13.994484 ] Epoch 425 batch   50/67 - Train accuracy: 0.9802, Validation accuracy: 0.2434, Loss: 0.0453
# [ 2019-02-16 11:20:51.817383 ] Epoch 426 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.3279, Loss: 0.0455
# [ 2019-02-16 11:21:29.740540 ] Epoch 427 batch   50/67 - Train accuracy: 0.9909, Validation accuracy: 0.3474, Loss: 0.0328
# [ 2019-02-16 11:22:07.625771 ] Epoch 428 batch   50/67 - Train accuracy: 0.9897, Validation accuracy: 0.2941, Loss: 0.0435
# [ 2019-02-16 11:22:45.462925 ] Epoch 429 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.2816, Loss: 0.0338
# [ 2019-02-16 11:23:23.419388 ] Epoch 430 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.2923, Loss: 0.0417
# [ 2019-02-16 11:24:01.520980 ] Epoch 431 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.3257, Loss: 0.0296
# [ 2019-02-16 11:24:39.521695 ] Epoch 432 batch   50/67 - Train accuracy: 0.9928, Validation accuracy: 0.2371, Loss: 0.0388
# [ 2019-02-16 11:25:17.579121 ] Epoch 433 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.2915, Loss: 0.0420
# [ 2019-02-16 11:25:55.449670 ] Epoch 434 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.3327, Loss: 0.0351
# [ 2019-02-16 11:26:33.350911 ] Epoch 435 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.2923, Loss: 0.0478
# [ 2019-02-16 11:27:11.301755 ] Epoch 436 batch   50/67 - Train accuracy: 0.9855, Validation accuracy: 0.2923, Loss: 0.0353
# [ 2019-02-16 11:27:49.284004 ] Epoch 437 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.3243, Loss: 0.0422
# [ 2019-02-16 11:28:27.274162 ] Epoch 438 batch   50/67 - Train accuracy: 0.9989, Validation accuracy: 0.2526, Loss: 0.0462
# [ 2019-02-16 11:29:05.248319 ] Epoch 439 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.3051, Loss: 0.0335
# [ 2019-02-16 11:29:43.115152 ] Epoch 440 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.2893, Loss: 0.0417
# [ 2019-02-16 11:30:21.089908 ] Epoch 441 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.2717, Loss: 0.0333
# [ 2019-02-16 11:30:59.054922 ] Epoch 442 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.2798, Loss: 0.0401
# [ 2019-02-16 11:31:36.966973 ] Epoch 443 batch   50/67 - Train accuracy: 0.9901, Validation accuracy: 0.2971, Loss: 0.0433
# [ 2019-02-16 11:32:14.814619 ] Epoch 444 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.2897, Loss: 0.0327
# [ 2019-02-16 11:32:52.787846 ] Epoch 445 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.2739, Loss: 0.0403
# [ 2019-02-16 11:33:30.742898 ] Epoch 446 batch   50/67 - Train accuracy: 0.9790, Validation accuracy: 0.3037, Loss: 0.0466
# [ 2019-02-16 11:34:08.654263 ] Epoch 447 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.3081, Loss: 0.0377
# [ 2019-02-16 11:34:46.685081 ] Epoch 448 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.2952, Loss: 0.0345
# [ 2019-02-16 11:35:24.556459 ] Epoch 449 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.3265, Loss: 0.0361
# [ 2019-02-16 11:36:02.454072 ] Epoch 450 batch   50/67 - Train accuracy: 0.9954, Validation accuracy: 0.3191, Loss: 0.0437
# [ 2019-02-16 11:36:40.386859 ] Epoch 451 batch   50/67 - Train accuracy: 0.9992, Validation accuracy: 0.3232, Loss: 0.0378
# [ 2019-02-16 11:37:18.218552 ] Epoch 452 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.3283, Loss: 0.0426
# [ 2019-02-16 11:37:56.120375 ] Epoch 453 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.2974, Loss: 0.0327
# [ 2019-02-16 11:38:33.987358 ] Epoch 454 batch   50/67 - Train accuracy: 0.9722, Validation accuracy: 0.3074, Loss: 0.0349
# [ 2019-02-16 11:39:11.983701 ] Epoch 455 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.3533, Loss: 0.0348
# [ 2019-02-16 11:39:49.964396 ] Epoch 456 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.3342, Loss: 0.0371
# [ 2019-02-16 11:40:27.816634 ] Epoch 457 batch   50/67 - Train accuracy: 0.9958, Validation accuracy: 0.2912, Loss: 0.0447
# [ 2019-02-16 11:41:05.740113 ] Epoch 458 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.2437, Loss: 0.0336
# [ 2019-02-16 11:41:43.621030 ] Epoch 459 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.3643, Loss: 0.0368
# [ 2019-02-16 11:42:21.516913 ] Epoch 460 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.2960, Loss: 0.0301
# [ 2019-02-16 11:42:59.431723 ] Epoch 461 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.3636, Loss: 0.0357
# [ 2019-02-16 11:43:37.335012 ] Epoch 462 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.3265, Loss: 0.0239
# [ 2019-02-16 11:44:15.383429 ] Epoch 463 batch   50/67 - Train accuracy: 0.9962, Validation accuracy: 0.3489, Loss: 0.0332
# [ 2019-02-16 11:44:53.414826 ] Epoch 464 batch   50/67 - Train accuracy: 0.9909, Validation accuracy: 0.3290, Loss: 0.0398
# [ 2019-02-16 11:45:31.329704 ] Epoch 465 batch   50/67 - Train accuracy: 0.9813, Validation accuracy: 0.3581, Loss: 0.0306
# [ 2019-02-16 11:46:09.125654 ] Epoch 466 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.3434, Loss: 0.0338
# [ 2019-02-16 11:46:47.060152 ] Epoch 467 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.3540, Loss: 0.0421
# [ 2019-02-16 11:47:24.991136 ] Epoch 468 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.3434, Loss: 0.0460
# [ 2019-02-16 11:48:02.842094 ] Epoch 469 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.3147, Loss: 0.0320
# [ 2019-02-16 11:48:40.771003 ] Epoch 470 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.2938, Loss: 0.0370
# [ 2019-02-16 11:49:18.675985 ] Epoch 471 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.3493, Loss: 0.0398
# [ 2019-02-16 11:49:56.678003 ] Epoch 472 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.3114, Loss: 0.0430
# [ 2019-02-16 11:50:34.534759 ] Epoch 473 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.2842, Loss: 0.0295
# [ 2019-02-16 11:51:12.435747 ] Epoch 474 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.2993, Loss: 0.0339
# [ 2019-02-16 11:51:50.369748 ] Epoch 475 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.3074, Loss: 0.0386
# [ 2019-02-16 11:52:28.330019 ] Epoch 476 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.2643, Loss: 0.0484
# [ 2019-02-16 11:53:06.227590 ] Epoch 477 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.3757, Loss: 0.0306
# [ 2019-02-16 11:53:44.097753 ] Epoch 478 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.3985, Loss: 0.0362
# [ 2019-02-16 11:54:22.107944 ] Epoch 479 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.3250, Loss: 0.0410
# [ 2019-02-16 11:55:00.063792 ] Epoch 480 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.4107, Loss: 0.0371
# [ 2019-02-16 11:55:37.899942 ] Epoch 481 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.2949, Loss: 0.0398
# [ 2019-02-16 11:56:15.861542 ] Epoch 482 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.3596, Loss: 0.0369
# [ 2019-02-16 11:56:53.773652 ] Epoch 483 batch   50/67 - Train accuracy: 0.9924, Validation accuracy: 0.3607, Loss: 0.0325
# [ 2019-02-16 11:57:31.641115 ] Epoch 484 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.2812, Loss: 0.0416
# [ 2019-02-16 11:58:09.551683 ] Epoch 485 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.3647, Loss: 0.0377
# [ 2019-02-16 11:58:47.432380 ] Epoch 486 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.2787, Loss: 0.0443
# [ 2019-02-16 11:59:25.453390 ] Epoch 487 batch   50/67 - Train accuracy: 0.9928, Validation accuracy: 0.3110, Loss: 0.0282
# [ 2019-02-16 12:00:03.409706 ] Epoch 488 batch   50/67 - Train accuracy: 0.9775, Validation accuracy: 0.2938, Loss: 0.0315
# [ 2019-02-16 12:00:41.373903 ] Epoch 489 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.2794, Loss: 0.0320
# [ 2019-02-16 12:01:19.178413 ] Epoch 490 batch   50/67 - Train accuracy: 0.9966, Validation accuracy: 0.3121, Loss: 0.0322
# [ 2019-02-16 12:01:57.137861 ] Epoch 491 batch   50/67 - Train accuracy: 0.9996, Validation accuracy: 0.3386, Loss: 0.0366
# [ 2019-02-16 12:02:34.933890 ] Epoch 492 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.2949, Loss: 0.0364
# [ 2019-02-16 12:03:12.825234 ] Epoch 493 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.2824, Loss: 0.0262
# [ 2019-02-16 12:03:50.730641 ] Epoch 494 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.2379, Loss: 0.0215
# [ 2019-02-16 12:04:28.666525 ] Epoch 495 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.2437, Loss: 0.0469
# [ 2019-02-16 12:05:06.576430 ] Epoch 496 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.2963, Loss: 0.0341
# [ 2019-02-16 12:05:44.606928 ] Epoch 497 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.2779, Loss: 0.0395
# [ 2019-02-16 12:06:22.436207 ] Epoch 498 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.3077, Loss: 0.0365
# [ 2019-02-16 12:07:00.320652 ] Epoch 499 batch   50/67 - Train accuracy: 1.0000, Validation accuracy: 0.2673, Loss: 0.0367
# Model trained and saved

# %%
# !mkdir model
# Out:
# mkdir: cannot create directory ‘model’: File exists

# %%
with tf.Session(graph=train_graph) as sess:
  sess.run(tf.global_variables_initializer())
  saver=tf.train.Saver()
  saver.save(sess,'./model')
  print('Model trained and saved')
# Out:
# Model trained and saved

# %%
def sentence_to_seq(sentence,vocab_to_int):
    results=[]
    for word in sentence.split(" "):
        if word in vocab_to_int:
            results.append(vocab_to_int[word])
        else:
            results.append(vocab_to_int['<UNK>'])
    return results

_,(source_word2int,target_word2int),(source_int2word,target_int2word)=load_preprocessed()
translate_sen='I am taking sulfamethoxazole, can I participate in any sports?'.lower()
translate_sen=sentence_to_seq(translate_sen,source_word2int)
loaded_graph=tf.Graph()
with tf.Session(graph=loaded_graph) as sess:
    loader=tf.train.import_meta_graph('./model/model_s.meta')
    loader.restore(sess,'./model/model_s')
    
    input_data=loaded_graph.get_tensor_by_name('Inputs:0')
    logits=loaded_graph.get_tensor_by_name('predictions:0')
    target_sequence_length=loaded_graph.get_tensor_by_name('target_sequence_length:0')
    keep_prob=loaded_graph.get_tensor_by_name('keep_prob:0')
    source_sequence_length=loaded_graph.get_tensor_by_name('source_sequence_length:0')
    translation=sess.run(logits,{input_data:[translate_sen]*batch_size,source_sequence_length:[len(translate_sen)]*batch_size,target_sequence_length:[len(translate_sen)*2]*batch_size,keep_prob:1.0})[0]
    print('Question:',' '.join([source_int2word[word] for word in translate_sen]))
    print('Answer:',' '.join([target_int2word[word] for word in translation]))
# Out:
# INFO:tensorflow:Restoring parameters from ./model/model_s
# Question: i am taking sulfamethoxazole, can i participate in any sports?
# Answer: no no durring and can be related to no no no no sports and you will be related to all

# %%
# !zip model.zip model/*
# Out:
#   adding: model/checkpoint (deflated 41%)
#   adding: model/model_s.data-00000-of-00001 (deflated 6%)
#   adding: model/model_s.index (deflated 54%)
#   adding: model/model_s.meta (deflated 93%)

# %%
source_text
# Out:
# 'questions\nMy son ,17, has a bruised and painful back also he is vomiting after being tackled Friday night while playing football ?\nI get a stitch pain  in  my hip mainly after  playing sports ?\nbeen playing volleyball a lot and cheering,lifting pepl. I was spiking and my shoulder hurts and now if i stretch it a bit it hurts. What should i do\n15 year old soccer player with lower back instability and very little hip instability with irritation, Is it dangerous if she still plays with back?\n16 year old girl, I play catcher. I\'ve been playing for years, but knees have been hurting after games and it feels hard to Bend them. (This is new)\n3 weeks ago hyperextended elbow in basketball game, pain only lasted 3 days. Pain returned suddenlywhen I swung my softball bat at practice last night?\n5 1/2 weeks ago I fell playing softball and hurt my thumb.both sides of my MCP joint are bothering me. Do normal sprains last this long?\n8 months ago I had ACL surgery, I did the patellar tendon way, I went to play soccer today and I felt something weird on the left side of my knee, help?\nAbout ago a week i was playing basketball and another ran into and i straight on my back wrist. I now have some pain.\nAfter playing football a month ago, i have developed a painful lump just above my shin. Each week i play it seems to get more and more painful.\nAfter playing golf yesterday, I have sore shoulder and I cannot lift up my arm. What should I do? : (\nAfter playing this morning\'s basketball game, my husband had left testicle pain?\nAfter sports I have tons of pain right below my knee knee but then it goes away until I play again?\nAm i crazy to think i could play softball 2 months after breaking my arm?\nBoth of my wrist have hurt for the last 2 weeks and I have an arm wrestling tournament this saturday. What should I do?\nCan MRI detect injury on the hip for a 8yr who played soccer for 2 yr. What can it be? After he stopped playing soccer he has on & off pain in the knee\nCan athletes contineue to play football with head pain and swelling?\nCan I get back pain from playing cricket?\nCan I play lacrosse with fractured scafoid if no pain is felt?\nCan i play soccer i sprained my ankle 2 months ago there is a hard bump on my ankle it hurts a bit to run can I play or do I have to wait and how long?\nCan throwing a baseball cause synovitis?\nCan throwing a baseball cause synovitis?\nCollided with someone else play I football. I got a knee to my thigh and my knee has a little discomfort on the side. Is it something serious?\nCould getting hit by a pitch in baseball cause a ruptured muscle?\nCould playing basketball be the reason why my back is hurting?\nDaughter has swollen knee with shooting pain to feet it does not hurt while playing basketball but does after done. She has had a t-ban issue in paste?\nDid I tear something? Playing soccer and did something last night to ankle and this morning I can\'t walk on it at all. Hurts on side and middle ofankle\nDo you think I can go back to playing rugby after having 49% of my meniscus removed?\nDoctors can you tell me when should I go back to playing basketball after an ankle sprain?\nDuring Sept in a field hockey game the ball was driven into my ankle and it swelled and bruised.  Now it is still a  bruised and swollen but why?\nEverytime my husband plays basketball his right heel is always hurting for 2-3 days. What do u think it is and what to do to prevent this?\nFell while playing sports, incredibly painful knee? I\'m in my teens, I fell during a soccer game and 2 days later it\'s still incredibly painful. There\'s no bruise or skin missing or anything, and I can move my knee without any pain, but when I put weight\nFour months ago I played rugby and after the game my right wrist started to pain until today?\nGot kneed in upper quad while playing basketball. Hurts bad at muscle level. I\'m limping. Is this a Charlie horse? Am I now at risk for DVT??\nGrade 1 or 2 hamstring strain, its an annoying ...

# %%
from google.colab import files

files.download('model.zip')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-28-dd0b6991d687> in <module>()
#       1 from google.colab import files
#       2
# ----> 3 files.download('model.zip')
#
# /usr/local/lib/python3.6/dist-packages/google/colab/files.py in download(filename)
#     176       'port': port,
#     177       'path': _os.path.abspath(filename),
# --> 178       'name': _os.path.basename(filename),
#     179   })
#
# /usr/local/lib/python3.6/dist-packages/google/colab/output/_js.py in eval_js(script, ignore_result)
#      37   if ignore_result:
#      38     return
# ---> 39   return _message.read_reply_from_input(request_id)
#      40
#      41
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#      99     reply = _read_next_input_message()
#     100     if reply == _NOT_READY or not isinstance(reply, dict):
# --> 101       time.sleep(0.025)
#     102       continue
#     103     if (reply.get('type') == 'colab_reply' and
#
# KeyboardInterrupt:

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
